# %%
from langchain_huggingface.embeddings import HuggingFaceEmbeddings
from langchain_classic.schema import Document
from langchain_chroma import Chroma
from dotenv import load_dotenv
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 # from langchain_huggingface.embeddings import HuggingFaceEmbeddings
# ----> 2 from langchain_classic.schema import Document
#       3 # from langchain_chroma import Chroma
#       4 # from dotenv import load_dotenv
#
# File d:\Data-Sorting\Langchain\venvv\Lib\site-packages\langchain_classic\schema\__init__.py:21
#       8 from langchain_core.messages import (
#       9     AIMessage,
#      10     BaseMessage,
#    (...)     18     messages_to_dict,
#      19 )
#      20 from langchain_core.messages.base import message_to_dict
# ---> 21 from langchain_core.output_parsers import (
#      22     BaseLLMOutputParser,
#      23     BaseOutputParser,
#      24     StrOutputParser,
#      25 )
#      26 from langchain_core.outputs import (
#      27     ChatGeneration,
#      28     ChatResult,
#    (...)     31     RunInfo,
#      32 )
#      33 from langchain_core.prompt_values import PromptValue
#
# File <frozen importlib._bootstrap>:1412, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File d:\Data-Sorting\Langchain\venvv\Lib\site-packages\langchain_core\output_parsers\__init__.py:95, in __getattr__(attr_name)
#      93 def __getattr__(attr_name: str) -> object:
#      94     module_name = _dynamic_imports.get(attr_name)
# ---> 95     result = import_attr(attr_name, module_name, __spec__.parent)
#      96     globals()[attr_name] = result
#      97     return result
#
# File d:\Data-Sorting\Langchain\venvv\Lib\site-packages\langchain_core\_import_utils.py:35, in import_attr(attr_name, module_name, package)
#      33 else:
#      34     try:
# ---> 35         module = import_module(f".{module_name}", package=package)
#      36     except ModuleNotFoundError as err:
#      37         msg = f"module '{package!r}.{module_name!r}' not found ({err})"
#
# File ~\anaconda3\Lib\importlib\__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File d:\Data-Sorting\Langchain\venvv\Lib\site-packages\langchain_core\output_parsers\base.py:16
#       7 from typing import (
#       8     TYPE_CHECKING,
#       9     Any,
#      10     Generic,
#      11     TypeVar,
#      12 )
#      14 from typing_extensions import override
# ---> 16 from langchain_core.language_models import LanguageModelOutput
#      17 from langchain_core.messages import AnyMessage, BaseMessage
#      18 from langchain_core.outputs import ChatGeneration, Generation
#
# File <frozen importlib._bootstrap>:1412, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File d:\Data-Sorting\Langchain\venvv\Lib\site-packages\langchain_core\language_models\__init__.py:110, in __getattr__(attr_name)
#     108 def __getattr__(attr_name: str) -> object:
#     109     module_name = _dynamic_imports.get(attr_name)
# --> 110     result = import_attr(attr_name, module_name, __spec__.parent)
#     111     globals()[attr_name] = result
#     112     return result
#
# File d:\Data-Sorting\Langchain\venvv\Lib\site-packages\langchain_core\_import_utils.py:35, in import_attr(attr_name, module_name, package)
#      33 else:
#      34     try:
# ---> 35         module = import_module(f".{module_name}", package=package)
#      36     except ModuleNotFoundError as err:
#      37         msg = f"module '{package!r}.{module_name!r}' not found ({err})"
#
# File ~\anaconda3\Lib\importlib\__init__.py:90, in import_module(name, package)
#      88             break
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File d:\Data-Sorting\Langchain\venvv\Lib\site-packages\langchain_core\language_models\base.py:41
#      38     from langchain_core.outputs import LLMResult
#      40 try:
# ---> 41     from transformers import GPT2TokenizerFast  # type: ignore[import-not-found]
#      43     _HAS_TRANSFORMERS = True
#      44 except ImportError:
#
# File d:\Data-Sorting\Langchain\venvv\Lib\site-packages\transformers\__init__.py:958
#     954 import sys
#     956 _import_structure = {k: set(v) for k, v in _import_structure.items()}
# --> 958 import_structure = define_import_structure(Path(__file__).parent / "models", prefix="models")
#     959 import_structure[frozenset({})].update(_import_structure)
#     961 sys.modules[__name__] = _LazyModule(
#     962     __name__,
#     963     globals()["__file__"],
#    (...)    966     extra_objects={"__version__": __version__},
#     967 )
#
# File d:\Data-Sorting\Langchain\venvv\Lib\site-packages\transformers\utils\import_utils.py:2867, in define_import_structure(module_path, prefix)
#    2843 @lru_cache
#    2844 def define_import_structure(module_path: str, prefix: Optional[str] = None) -> IMPORT_STRUCTURE_T:
#    2845     """
#    2846     This method takes a module_path as input and creates an import structure digestible by a _LazyModule.
#    2847
#    (...)   2865     If `prefix` is not None, it will add that prefix to all keys in the returned dict.
#    2866     """
# -> 2867     import_structure = create_import_structure_from_path(module_path)
#    2868     spread_dict = spread_import_structure(import_structure)
#    2870     if prefix is None:
#
# File d:\Data-Sorting\Langchain\venvv\Lib\site-packages\transformers\utils\import_utils.py:2580, in create_import_structure_from_path(module_path)
#    2578 for f in os.listdir(module_path):
#    2579     if f != "__pycache__" and os.path.isdir(os.path.join(module_path, f)):
# -> 2580         import_structure[f] = create_import_structure_from_path(os.path.join(module_path, f))
#    2582     elif not os.path.isdir(os.path.join(directory, f)):
#    2583         adjacent_modules.append(f)
#
# File d:\Data-Sorting\Langchain\venvv\Lib\site-packages\transformers\utils\import_utils.py:2604, in create_import_structure_from_path(module_path)
#    2601 if not module_name.endswith(".py"):
#    2602     continue
# -> 2604 with open(os.path.join(directory, module_name), encoding="utf-8") as f:
#    2605     file_content = f.read()
#    2607 # Remove the .py suffix
#
# File <frozen codecs>:309, in __init__(self, errors)
#
# KeyboardInterrupt:

# %%
load_dotenv()

# %%
# Create documents
doc1 = Document(
    page_content="This is a test document about machine learning. Machine Learning is fast growing field in today's world. Those without sound knowledge of maths now can work in this domain",
    metadata =({'source':'Machine Learning'})
)
doc2 = Document(
    page_content="This is a test document about data analysis. Data Analysis is considered as a sub-branch of machine learning. It involves inspecting, cleansing, transforming, and modeling data to discover useful information.",
    metadata =({'source':'Data Analysis'})
)
doc3 = Document(
    page_content="This is a test document about robotics. Robotics is an interdisciplinary branch of engineering and science that includes mechanical engineering, electronic engineering, information engineering, computer science, and others. Robotics deals with the design, construction, operation, and use of robots.",
    metadata =({'source':'Robotics'})
)
doc4 = Document(
    page_content="This is a test document about ethical hacking. Ethical Hacking is the practice of legally breaking into computers and devices to test an organization's defenses. These hackers are often referred to as 'white hats.'",
    metadata =({'source':'Ethical Hacking'})
)
doc5 = Document(
    page_content="This is a test document about devops. Devops is a set of practices that combines software development (Dev) and IT operations (Ops). It aims to shorten the systems development life cycle and provide continuous delivery with high software quality.",
    metadata =({'source':'Devops'})
)

# %%
doc = [doc1, doc2, doc3, doc4, doc5]

# %%
# Create Embedding
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# %%
vector_store = Chroma(
    embedding_function=embeddings,
    persist_directory='../VectorStore/chroma_db',
    collection_name='software_jobs'
)

# %%
# add documents
vector_store.add_documents(documents=doc)

# %%
# view documents
vector_store.get(include=['embeddings','metadatas','documents'])

# %%
# search documnets
vector_store.similarity_search(query='Which domain of job requires maths knowledge', k=2)

# %%
# search with similarity score
vector_store.similarity_search_with_score(
    query='People working in which domain are called as white hats?',
    k=2
)

# %%
# meta data filtering
vector_store.similarity_search_with_score(
    query='', # for metadata filtering keep it empty
    filter = {'source':'Data Analysis'}
)

# %%
# update document
updated_doc = Document(
    page_content="Machine learning is a branch of Artificial Intelligence that focuses on developing models and algorithms that let computers learn from data without being explicitly programmed for every task. In simple words, ML teaches the systems to think and understand like humans by learning from the data.",
    metadata={'source':'Machine Learning'}
)
vector_store.update_document(document_id='5fa08ab3-e180-49b9-8132-3074b30ae7b8' , document=updated_doc)

# %%
vector_store.get(include=['embeddings','metadatas','documents'])

# %%
# delete document
vector_store.delete(ids=['0da63be7-1629-41b8-8aa1-f4bd620f02de'])

# %%
# view document
vector_store.get(include=['embeddings','metadatas','documents'])
